# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=66&offset=66&sort=sale'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
#### Your code

response = requests.get(url, headers=headers)
results = response.json()
results

flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   LE112O027-K11  COURTSTAR SPORT - Baskets basses - dress blue/...
# 1   GOG22G005-K11        SKINNY MID WASH - Jeans Skinny - blue denim
# 2   SK212O01T-Q11                   D'LITES - Baskets basses - black
# 3   VA215O03L-G11  OLD SKOOL - Baskets basses - red/black/true white
# 4   PU122E02F-K11             MOTOR - Pantalon de survêtement - blue
# ..            ...                                                ...
# 79  LE222P00M-K11           LEVI'S® HOUSEMARK - Polo - sodalite blue
# 80  YO122G05L-Q11                            Jean slim - black denim
# 81  PUC12O08V-A11                             Baskets basses - white
# 82  C1822O04Z-A11  MONOGRAM POCKET SLIM TEE - T-shirt imprimé - w...
# 83  L4722O01X-Q11                            T-shirt basique - black
#
#                                                 sizes  \
# 0                        [39, 40, 42, 43, 44, 45, 46]
# 1                                [28, 30, 32, 34, 36]
# 2            [40, 41, 42, 43, 44, 45, 46, 47.5, 48.5]
# 3   [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 4                                  [S, M, L, XL, XXL]
# ..                                                ...
# 79                                 [S, M, L, XL, XXL]
# 80  [27x30, 27x32, 27x34, 28x30, 28x32, 28x34, 30x...
# 81                           [40, 41, 42, 43, 44, 45]
# 82                             [XS, S, M, L, XL, XXL]
# 83                   [XXS, XS, S, M, L, XL, XXL, 3XL]
#
#                                               url_key  \
# 0   le-coq-sportif-courtstar-sport-baskets-basses-...
# 1   good-for-nothing-skinny-mid-wash-jeans-skinny-...
# 2   skechers-sport-d-lites-baskets-basses-black-sk...
# 3   vans-old-skool-baskets-basses-redblacktrue-whi...
# 4   puma-bmw-motorsport-pantalon-de-survetement-bl...
# ..                                                ...
# 79           levisr-housemark-polo-polo-le222p00m-k11
# 80       yourturn-jean-slim-black-denim-yo122g05l-q11
# 81     pullandbear-baskets-basses-white-puc12o08v-a11
# 82  calvin-klein-jeans-monogram-pocket-tee-t-shirt...
# 83   lacoste-live-t-shirt-basique-black-l4722o01x-q11
#
#                                                 media          brand_name  \
# 0   [{'path': 'LE/11/2O/02/7K/11/LE112O027-K11@5.j...      le coq sportif
# 1   [{'path': 'GO/G2/2G/00/5K/11/GOG22G005-K11@4.j...    Good For Nothing
# 2   [{'path': 'SK/21/2O/01/TQ/11/SK212O01T-Q11@8.j...      Skechers Sport
# 3   [{'path': 'VA/21/5O/03/LG/11/VA215O03L-G11@2.j...                Vans
# 4   [{'path': 'PU/12/2E/02/FK/11/PU122E02F-K11@12....                Puma
# ..                                                ...                 ...
# 79  [{'path': 'LE/22/2P/00/MK/11/LE222P00M-K11@8.j...             Levi's®
# 80  [{'path': 'YO/12/2G/05/LQ/11/YO122G05L-Q11@7.j...            YOURTURN
# 81  [{'path': 'PU/C1/2O/08/VA/11/PUC12O08V-A11@11....           PULL&BEAR
# 82  [{'path': 'C1/82/2O/04/ZA/11/C1822O04Z-A11@9.j...  Calvin Klein Jeans
# 83  [{'path': 'L4/72/2O/01/XQ/11/L4722O01X-Q11@10....        Lacoste LIVE
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'LE112O027-K11', 'url_key': 'le-coq-s...
# 1        False  [{'sku': 'GOG22G005-K11', 'url_key': 'good-for...
# 2        False  [{'sku': 'SK212O01T-Q11', 'url_key': 'skechers...
# 3        False  [{'sku': 'VA215O03L-G11', 'url_key': 'vans-old...
# 4        False  [{'sku': 'PU122E02F-K11', 'url_key': 'puma-bmw...
# ..         ...                                                ...
# 79       False  [{'sku': 'LE222P00M-K11', 'url_key': 'levisr-h...
# 80       False  [{'sku': 'YO122G05L-Q11', 'url_key': 'yourturn...
# 81       False  [{'sku': 'PUC12O08V-A11', 'url_key': 'pullandb...
# 82       False  [{'sku': 'C1822O04Z-A11', 'url_key': 'calvin-k...
# 83       False  [{'sku': 'L4722O01X-Q11', 'url_key': 'lacoste-...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': '-40%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': '-45%', 'tra...          shoe
# 3   [{'key': 'discountRate', 'value': '-40%', 'tra...          shoe
# 4   [{'key': 'discountRate', 'value': '-31%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-50%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-50%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-47%', 'tra...          shoe
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': 'Jusqu’à -25...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        79,95 €           55,95 €
# 1                 []        59,95 €           35,95 €
# 2                 []        69,95 €           38,45 €
# 3                 []        79,95 €           47,95 €
# 4                 []        85,00 €           59,00 €
# ..               ...            ...               ...
# 79                []        48,95 €           24,45 €
# 80                []        38,99 €           19,49 €
# 81                []        29,99 €           15,99 €
# 82                []        29,95 €           23,95 €
# 83                []        49,95 €           37,45 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                        True                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                    True
#
#     price.has_discount_on_selected_sizes_only outfits
# 0                                       False     NaN
# 1                                       False     NaN
# 2                                       False     NaN
# 3                                       False     NaN
# 4                                       False     NaN
# ..                                        ...     ...
# 79                                      False     NaN
# 80                                      False     NaN
# 81                                      False     NaN
# 82                                      False     NaN
# 83                                      False     NaN
#
# [84 rows x 18 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    response = requests.get(url,headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1 = flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
#                                                             name  \
# sku
# LE112O027-K11  COURTSTAR SPORT - Baskets basses - dress blue/...
# GOG22G005-K11        SKINNY MID WASH - Jeans Skinny - blue denim
# SK212O01T-Q11                   D'LITES - Baskets basses - black
# VA215O03L-G11  OLD SKOOL - Baskets basses - red/black/true white
# PU122E02F-K11             MOTOR - Pantalon de survêtement - blue
# ...                                                          ...
# YO122G05L-Q11                            Jean slim - black denim
# PUC12O08V-A11                             Baskets basses - white
# C1822O04Z-A11  MONOGRAM POCKET SLIM TEE - T-shirt imprimé - w...
# L4722O01X-Q11                            T-shirt basique - black
# AD115O0DR-Q11  CONTINENTAL VULCANIZED SKATEBOARD SHOES - Bask...
#
#                                                            sizes  \
# sku
# LE112O027-K11                       [39, 40, 42, 43, 44, 45, 46]
# GOG22G005-K11                               [28, 30, 32, 34, 36]
# SK212O01T-Q11           [40, 41, 42, 43, 44, 45, 46, 47.5, 48.5]
# VA215O03L-G11  [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# PU122E02F-K11                                 [S, M, L, XL, XXL]
# ...                                                          ...
# YO122G05L-Q11  [27x30, 27x32, 27x34, 28x30, 28x32, 28x34, 30x...
# PUC12O08V-A11                           [40, 41, 42, 43, 44, 45]
# C1822O04Z-A11                             [XS, S, M, L, XL, XXL]
# L4722O01X-Q11                   [XXS, XS, S, M, L, XL, XXL, 3XL]
# AD115O0DR-Q11  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
#
#                                                          url_key  \
# sku
# LE112O027-K11  le-coq-sportif-courtstar-sport-baskets-basses-...
# GOG22G005-K11  good-for-nothing-skinny-mid-wash-jeans-skinny-...
# SK212O01T-Q11  skechers-sport-d-lites-baskets-basses-black-sk...
# VA215O03L-G11  vans-old-skool-baskets-basses-redblacktrue-whi...
# PU122E02F-K11  puma-bmw-motorsport-pantalon-de-survetement-bl...
# ...                                                          ...
# YO122G05L-Q11       yourturn-jean-slim-black-denim-yo122g05l-q11
# PUC12O08V-A11     pullandbear-baskets-basses-white-puc12o08v-a11
# C1822O04Z-A11  calvin-klein-jeans-monogram-pocket-tee-t-shirt...
# L4722O01X-Q11   lacoste-live-t-shirt-basique-black-l4722o01x-q11
# AD115O0DR-Q11  adidas-originals-continental-baskets-basses-ad...
#
#                                                            media  \
# sku
# LE112O027-K11  [{'path': 'LE/11/2O/02/7K/11/LE112O027-K11@5.j...
# GOG22G005-K11  [{'path': 'GO/G2/2G/00/5K/11/GOG22G005-K11@4.j...
# SK212O01T-Q11  [{'path': 'SK/21/2O/01/TQ/11/SK212O01T-Q11@8.j...
# VA215O03L-G11  [{'path': 'VA/21/5O/03/LG/11/VA215O03L-G11@2.j...
# PU122E02F-K11  [{'path': 'PU/12/2E/02/FK/11/PU122E02F-K11@12....
# ...                                                          ...
# YO122G05L-Q11  [{'path': 'YO/12/2G/05/LQ/11/YO122G05L-Q11@7.j...
# PUC12O08V-A11  [{'path': 'PU/C1/2O/08/VA/11/PUC12O08V-A11@11....
# C1822O04Z-A11  [{'path': 'C1/82/2O/04/ZA/11/C1822O04Z-A11@9.j...
# L4722O01X-Q11  [{'path': 'L4/72/2O/01/XQ/11/L4722O01X-Q11@10....
# AD115O0DR-Q11  [{'path': 'AD/11/5O/0D/RQ/11/AD115O0DR-Q11@2.j...
#
#                        brand_name  is_premium  \
# sku
# LE112O027-K11      le coq sportif       False
# GOG22G005-K11    Good For Nothing       False
# SK212O01T-Q11      Skechers Sport       False
# VA215O03L-G11                Vans       False
# PU122E02F-K11                Puma       False
# ...                           ...         ...
# YO122G05L-Q11            YOURTURN       False
# PUC12O08V-A11           PULL&BEAR       False
# C1822O04Z-A11  Calvin Klein Jeans       False
# L4722O01X-Q11        Lacoste LIVE       False
# AD115O0DR-Q11    adidas Originals       False
#
#                                                  family_articles  \
# sku
# LE112O027-K11  [{'sku': 'LE112O027-K11', 'url_key': 'le-coq-s...
# GOG22G005-K11  [{'sku': 'GOG22G005-K11', 'url_key': 'good-for...
# SK212O01T-Q11  [{'sku': 'SK212O01T-Q11', 'url_key': 'skechers...
# VA215O03L-G11  [{'sku': 'VA215O03L-G11', 'url_key': 'vans-old...
# PU122E02F-K11  [{'sku': 'PU122E02F-K11', 'url_key': 'puma-bmw...
# ...                                                          ...
# YO122G05L-Q11  [{'sku': 'YO122G05L-Q11', 'url_key': 'yourturn...
# PUC12O08V-A11  [{'sku': 'PUC12O08V-A11', 'url_key': 'pullandb...
# C1822O04Z-A11  [{'sku': 'C1822O04Z-A11', 'url_key': 'calvin-k...
# L4722O01X-Q11  [{'sku': 'L4722O01X-Q11', 'url_key': 'lacoste-...
# AD115O0DR-Q11  [{'sku': 'AD115O0DR-Q11', 'url_key': 'adidas-o...
#
#                                                            flags  \
# sku
# LE112O027-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...
# GOG22G005-K11  [{'key': 'discountRate', 'value': '-40%', 'tra...
# SK212O01T-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# VA215O03L-G11  [{'key': 'discountRate', 'value': '-40%', 'tra...
# PU122E02F-K11  [{'key': 'discountRate', 'value': '-31%', 'tra...
# ...                                                          ...
# YO122G05L-Q11  [{'key': 'discountRate', 'value': '-50%', 'tra...
# PUC12O08V-A11  [{'key': 'discountRate', 'value': '-47%', 'tra...
# C1822O04Z-A11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# L4722O01X-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# AD115O0DR-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -15...
#
#               product_group delivery_promises price.original  \
# sku
# LE112O027-K11          shoe                []        79,95 €
# GOG22G005-K11      clothing                []        59,95 €
# SK212O01T-Q11          shoe                []        69,95 €
# VA215O03L-G11          shoe                []        79,95 €
# PU122E02F-K11      clothing                []        85,00 €
# ...                     ...               ...            ...
# YO122G05L-Q11      clothing                []        38,99 €
# PUC12O08V-A11          shoe                []        29,99 €
# C1822O04Z-A11      clothing                []        29,95 €
# L4722O01X-Q11      clothing                []        49,95 €
# AD115O0DR-Q11          shoe                []        79,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# LE112O027-K11           55,95 €                       False
# GOG22G005-K11           35,95 €                       False
# SK212O01T-Q11           38,45 €                       False
# VA215O03L-G11           47,95 €                       False
# PU122E02F-K11           59,00 €                       False
# ...                         ...                         ...
# YO122G05L-Q11           19,49 €                       False
# PUC12O08V-A11           15,99 €                       False
# C1822O04Z-A11           23,95 €                       False
# L4722O01X-Q11           37,45 €                        True
# AD115O0DR-Q11           67,95 €                        True
#
#                price.has_different_original_prices  \
# sku
# LE112O027-K11                                False
# GOG22G005-K11                                False
# SK212O01T-Q11                                False
# VA215O03L-G11                                False
# PU122E02F-K11                                False
# ...                                            ...
# YO122G05L-Q11                                False
# PUC12O08V-A11                                False
# C1822O04Z-A11                                False
# L4722O01X-Q11                                False
# AD115O0DR-Q11                                False
#
#                price.has_different_promotional_prices  \
# sku
# LE112O027-K11                                   False
# GOG22G005-K11                                   False
# SK212O01T-Q11                                   False
# VA215O03L-G11                                   False
# PU122E02F-K11                                   False
# ...                                               ...
# YO122G05L-Q11                                   False
# PUC12O08V-A11                                   False
# C1822O04Z-A11                                   False
# L4722O01X-Q11                                    True
# AD115O0DR-Q11                                    True
#
#                price.has_discount_on_selected_sizes_only outfits
# sku
# LE112O027-K11                                      False     NaN
# GOG22G005-K11                                      False     NaN
# SK212O01T-Q11                                      False     NaN
# VA215O03L-G11                                      False     NaN
# PU122E02F-K11                                      False     NaN
# ...                                                  ...     ...
# YO122G05L-Q11                                      False     NaN
# PUC12O08V-A11                                      False     NaN
# C1822O04Z-A11                                      False     NaN
# L4722O01X-Q11                                      False     NaN
# AD115O0DR-Q11                                      False     NaN
#
# [28980 rows x 17 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'adidas Originals'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'adidas Originals'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
