# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=66&offset=66&sort=sale'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
response = requests.get(url, headers=headers)
results = response.json()

flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   SK212O01T-Q11                   D'LITES - Baskets basses - black
# 1   VA215O03L-G11  OLD SKOOL - Baskets basses - red/black/true white
# 2   PU122E02F-K11             MOTOR - Pantalon de survêtement - blue
# 3   GU122O0EW-K11  ORIGINAL LOGO CORE TEE - T-shirt à manches lon...
# 4   OS322E04A-C11  ONSMARK PANT - Pantalon classique - medium gre...
# ..            ...                                                ...
# 79  C1822O04Z-A11  MONOGRAM POCKET SLIM TEE - T-shirt imprimé - w...
# 80  L4722O01X-Q11                            T-shirt basique - black
# 81  AD115O0DR-Q11  CONTINENTAL VULCANIZED SKATEBOARD SHOES - Bask...
# 82  AD115O0AJ-A12  STAN SMITH - Baskets basses - footwear white/grey
# 83  H0422O02T-A11  CREW CHAIN 3 PACK - T-shirt basique - white/gr...
#
#                                                 sizes  \
# 0            [40, 41, 42, 43, 44, 45, 46, 47.5, 48.5]
# 1   [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 2                                  [S, M, L, XL, XXL]
# 3                              [XS, S, M, L, XL, XXL]
# 4   [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# ..                                                ...
# 79                             [XS, S, M, L, XL, XXL]
# 80                   [XXS, XS, S, M, L, XL, XXL, 3XL]
# 81  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 82  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# 83                             [XS, S, M, L, XL, XXL]
#
#                                               url_key  \
# 0   skechers-sport-d-lites-baskets-basses-black-sk...
# 1   vans-old-skool-baskets-basses-redblacktrue-whi...
# 2   puma-bmw-motorsport-pantalon-de-survetement-bl...
# 3   guess-original-logo-core-tee-t-shirt-a-manches...
# 4   only-and-sons-onsmark-pant-pantalon-classique-...
# ..                                                ...
# 79  calvin-klein-jeans-monogram-pocket-tee-t-shirt...
# 80   lacoste-live-t-shirt-basique-black-l4722o01x-q11
# 81  adidas-originals-continental-baskets-basses-ad...
# 82  adidas-originals-stan-smith-baskets-basses-ad1...
# 83  hollister-co-crew-3-pack-t-shirt-basique-white...
#
#                                                 media          brand_name  \
# 0   [{'path': 'SK/21/2O/01/TQ/11/SK212O01T-Q11@8.j...      Skechers Sport
# 1   [{'path': 'VA/21/5O/03/LG/11/VA215O03L-G11@2.j...                Vans
# 2   [{'path': 'PU/12/2E/02/FK/11/PU122E02F-K11@12....                Puma
# 3   [{'path': 'GU/12/2O/0E/WK/11/GU122O0EW-K11@11....               Guess
# 4   [{'path': 'OS/32/2E/04/AC/11/OS322E04A-C11@10....         Only & Sons
# ..                                                ...                 ...
# 79  [{'path': 'C1/82/2O/04/ZA/11/C1822O04Z-A11@9.j...  Calvin Klein Jeans
# 80  [{'path': 'L4/72/2O/01/XQ/11/L4722O01X-Q11@10....        Lacoste LIVE
# 81  [{'path': 'AD/11/5O/0D/RQ/11/AD115O0DR-Q11@2.j...    adidas Originals
# 82  [{'path': 'AD/11/5O/0A/JA/12/AD115O0AJ-A12@2.j...    adidas Originals
# 83  [{'path': 'H0/42/2O/02/TA/11/H0422O02T-A11@14....       Hollister Co.
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'SK212O01T-Q11', 'url_key': 'skechers...
# 1        False  [{'sku': 'VA215O03L-G11', 'url_key': 'vans-old...
# 2        False  [{'sku': 'PU122E02F-K11', 'url_key': 'puma-bmw...
# 3        False  [{'sku': 'GU122O0EW-K11', 'url_key': 'guess-or...
# 4        False  [{'sku': 'OS322E04A-C11', 'url_key': 'only-and...
# ..         ...                                                ...
# 79       False  [{'sku': 'C1822O04Z-A11', 'url_key': 'calvin-k...
# 80       False  [{'sku': 'L4722O01X-Q11', 'url_key': 'lacoste-...
# 81       False  [{'sku': 'AD115O0DR-Q11', 'url_key': 'adidas-o...
# 82       False  [{'sku': 'AD115O0AJ-A12', 'url_key': 'adidas-o...
# 83       False  [{'sku': 'H0422O02T-A11', 'url_key': 'holliste...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-45%', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': '-40%', 'tra...          shoe
# 2   [{'key': 'discountRate', 'value': '-31%', 'tra...      clothing
# 3   [{'key': 'discountRate', 'value': '-40%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': 'Jusqu’à -25...      clothing
# 81  [{'key': 'discountRate', 'value': 'Jusqu’à -15...          shoe
# 82  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# 83  [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        69,95 €           38,45 €
# 1                 []        79,95 €           47,95 €
# 2                 []        85,00 €           59,00 €
# 3                 []        34,95 €           20,95 €
# 4                 []        39,95 €           35,99 €
# ..               ...            ...               ...
# 79                []        29,95 €           23,95 €
# 80                []        49,95 €           37,45 €
# 81                []        79,95 €           67,95 €
# 82                []        99,95 €           84,95 €
# 83                []        34,95 €           29,65 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                        True                                False
# 81                        True                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                    True
# 81                                    True
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82  [{'id': 'Qe78PYDCQwK', 'url_key': '/outfits/Qe...
# 83                                                NaN
#
# [84 rows x 18 columns]

# %%
flattened_data1.columns
# Out:
# Index(['sku', 'name', 'sizes', 'url_key', 'media', 'brand_name', 'is_premium',
#        'family_articles', 'flags', 'product_group', 'delivery_promises',
#        'price.original', 'price.promotional', 'price.has_different_prices',
#        'price.has_different_original_prices',
#        'price.has_different_promotional_prices',
#        'price.has_discount_on_selected_sizes_only', 'outfits'],
#       dtype='object')

# %%
range(len(flattened_data1))
# Out:
# range(0, 84)

# %%
total_pages=results['pagination']['page_count']
total_pages
# Out:
# 346

# %%
# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    response = requests.get(url,headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1 = flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
#                                                             name  \
# sku
# SK212O01T-Q11                   D'LITES - Baskets basses - black
# VA215O03L-G11  OLD SKOOL - Baskets basses - red/black/true white
# PU122E02F-K11             MOTOR - Pantalon de survêtement - blue
# GU122O0EW-K11  ORIGINAL LOGO CORE TEE - T-shirt à manches lon...
# OS322E04A-C11  ONSMARK PANT - Pantalon classique - medium gre...
# ...                                                          ...
# PUC12O08V-A11                             Baskets basses - white
# C1822O04Z-A11  MONOGRAM POCKET SLIM TEE - T-shirt imprimé - w...
# L4722O01X-Q11                            T-shirt basique - black
# AD115O0DR-Q11  CONTINENTAL VULCANIZED SKATEBOARD SHOES - Bask...
# AD115O0AJ-A12  STAN SMITH - Baskets basses - footwear white/grey
#
#                                                            sizes  \
# sku
# SK212O01T-Q11           [40, 41, 42, 43, 44, 45, 46, 47.5, 48.5]
# VA215O03L-G11  [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# PU122E02F-K11                                 [S, M, L, XL, XXL]
# GU122O0EW-K11                             [XS, S, M, L, XL, XXL]
# OS322E04A-C11  [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# ...                                                          ...
# PUC12O08V-A11                           [40, 41, 42, 43, 44, 45]
# C1822O04Z-A11                             [XS, S, M, L, XL, XXL]
# L4722O01X-Q11                   [XXS, XS, S, M, L, XL, XXL, 3XL]
# AD115O0DR-Q11  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
# AD115O0AJ-A12  [36, 38, 40, 42, 44, 46, 48, 36 2/3, 37 1/3, 3...
#
#                                                          url_key  \
# sku
# SK212O01T-Q11  skechers-sport-d-lites-baskets-basses-black-sk...
# VA215O03L-G11  vans-old-skool-baskets-basses-redblacktrue-whi...
# PU122E02F-K11  puma-bmw-motorsport-pantalon-de-survetement-bl...
# GU122O0EW-K11  guess-original-logo-core-tee-t-shirt-a-manches...
# OS322E04A-C11  only-and-sons-onsmark-pant-pantalon-classique-...
# ...                                                          ...
# PUC12O08V-A11     pullandbear-baskets-basses-white-puc12o08v-a11
# C1822O04Z-A11  calvin-klein-jeans-monogram-pocket-tee-t-shirt...
# L4722O01X-Q11   lacoste-live-t-shirt-basique-black-l4722o01x-q11
# AD115O0DR-Q11  adidas-originals-continental-baskets-basses-ad...
# AD115O0AJ-A12  adidas-originals-stan-smith-baskets-basses-ad1...
#
#                                                            media  \
# sku
# SK212O01T-Q11  [{'path': 'SK/21/2O/01/TQ/11/SK212O01T-Q11@8.j...
# VA215O03L-G11  [{'path': 'VA/21/5O/03/LG/11/VA215O03L-G11@2.j...
# PU122E02F-K11  [{'path': 'PU/12/2E/02/FK/11/PU122E02F-K11@12....
# GU122O0EW-K11  [{'path': 'GU/12/2O/0E/WK/11/GU122O0EW-K11@11....
# OS322E04A-C11  [{'path': 'OS/32/2E/04/AC/11/OS322E04A-C11@10....
# ...                                                          ...
# PUC12O08V-A11  [{'path': 'PU/C1/2O/08/VA/11/PUC12O08V-A11@11....
# C1822O04Z-A11  [{'path': 'C1/82/2O/04/ZA/11/C1822O04Z-A11@9.j...
# L4722O01X-Q11  [{'path': 'L4/72/2O/01/XQ/11/L4722O01X-Q11@10....
# AD115O0DR-Q11  [{'path': 'AD/11/5O/0D/RQ/11/AD115O0DR-Q11@2.j...
# AD115O0AJ-A12  [{'path': 'AD/11/5O/0A/JA/12/AD115O0AJ-A12@2.j...
#
#                        brand_name  is_premium  \
# sku
# SK212O01T-Q11      Skechers Sport       False
# VA215O03L-G11                Vans       False
# PU122E02F-K11                Puma       False
# GU122O0EW-K11               Guess       False
# OS322E04A-C11         Only & Sons       False
# ...                           ...         ...
# PUC12O08V-A11           PULL&BEAR       False
# C1822O04Z-A11  Calvin Klein Jeans       False
# L4722O01X-Q11        Lacoste LIVE       False
# AD115O0DR-Q11    adidas Originals       False
# AD115O0AJ-A12    adidas Originals       False
#
#                                                  family_articles  \
# sku
# SK212O01T-Q11  [{'sku': 'SK212O01T-Q11', 'url_key': 'skechers...
# VA215O03L-G11  [{'sku': 'VA215O03L-G11', 'url_key': 'vans-old...
# PU122E02F-K11  [{'sku': 'PU122E02F-K11', 'url_key': 'puma-bmw...
# GU122O0EW-K11  [{'sku': 'GU122O0EW-K11', 'url_key': 'guess-or...
# OS322E04A-C11  [{'sku': 'OS322E04A-C11', 'url_key': 'only-and...
# ...                                                          ...
# PUC12O08V-A11  [{'sku': 'PUC12O08V-A11', 'url_key': 'pullandb...
# C1822O04Z-A11  [{'sku': 'C1822O04Z-A11', 'url_key': 'calvin-k...
# L4722O01X-Q11  [{'sku': 'L4722O01X-Q11', 'url_key': 'lacoste-...
# AD115O0DR-Q11  [{'sku': 'AD115O0DR-Q11', 'url_key': 'adidas-o...
# AD115O0AJ-A12  [{'sku': 'AD115O0AJ-A12', 'url_key': 'adidas-o...
#
#                                                            flags  \
# sku
# SK212O01T-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# VA215O03L-G11  [{'key': 'discountRate', 'value': '-40%', 'tra...
# PU122E02F-K11  [{'key': 'discountRate', 'value': '-31%', 'tra...
# GU122O0EW-K11  [{'key': 'discountRate', 'value': '-40%', 'tra...
# OS322E04A-C11  [{'key': 'discountRate', 'value': '-10%', 'tra...
# ...                                                          ...
# PUC12O08V-A11  [{'key': 'discountRate', 'value': '-47%', 'tra...
# C1822O04Z-A11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# L4722O01X-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# AD115O0DR-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -15...
# AD115O0AJ-A12  [{'key': 'discountRate', 'value': '-15%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# SK212O01T-Q11          shoe                []        69,95 €
# VA215O03L-G11          shoe                []        79,95 €
# PU122E02F-K11      clothing                []        85,00 €
# GU122O0EW-K11      clothing                []        34,95 €
# OS322E04A-C11      clothing                []        39,95 €
# ...                     ...               ...            ...
# PUC12O08V-A11          shoe                []        29,99 €
# C1822O04Z-A11      clothing                []        29,95 €
# L4722O01X-Q11      clothing                []        49,95 €
# AD115O0DR-Q11          shoe                []        79,95 €
# AD115O0AJ-A12          shoe                []        99,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# SK212O01T-Q11           38,45 €                       False
# VA215O03L-G11           47,95 €                       False
# PU122E02F-K11           59,00 €                       False
# GU122O0EW-K11           20,95 €                       False
# OS322E04A-C11           35,99 €                       False
# ...                         ...                         ...
# PUC12O08V-A11           15,99 €                       False
# C1822O04Z-A11           23,95 €                       False
# L4722O01X-Q11           37,45 €                        True
# AD115O0DR-Q11           67,95 €                        True
# AD115O0AJ-A12           84,95 €                       False
#
#                price.has_different_original_prices  \
# sku
# SK212O01T-Q11                                False
# VA215O03L-G11                                False
# PU122E02F-K11                                False
# GU122O0EW-K11                                False
# OS322E04A-C11                                False
# ...                                            ...
# PUC12O08V-A11                                False
# C1822O04Z-A11                                False
# L4722O01X-Q11                                False
# AD115O0DR-Q11                                False
# AD115O0AJ-A12                                False
#
#                price.has_different_promotional_prices  \
# sku
# SK212O01T-Q11                                   False
# VA215O03L-G11                                   False
# PU122E02F-K11                                   False
# GU122O0EW-K11                                   False
# OS322E04A-C11                                   False
# ...                                               ...
# PUC12O08V-A11                                   False
# C1822O04Z-A11                                   False
# L4722O01X-Q11                                    True
# AD115O0DR-Q11                                    True
# AD115O0AJ-A12                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# SK212O01T-Q11                                      False
# VA215O03L-G11                                      False
# PU122E02F-K11                                      False
# GU122O0EW-K11                                      False
# OS322E04A-C11                                      False
# ...                                                  ...
# PUC12O08V-A11                                      False
# C1822O04Z-A11                                      False
# L4722O01X-Q11                                      False
# AD115O0DR-Q11                                      False
# AD115O0AJ-A12                                      False
#
#                                                          outfits
# sku
# SK212O01T-Q11                                                NaN
# VA215O03L-G11                                                NaN
# PU122E02F-K11                                                NaN
# GU122O0EW-K11                                                NaN
# OS322E04A-C11                                                NaN
# ...                                                          ...
# PUC12O08V-A11                                                NaN
# C1822O04Z-A11                                                NaN
# L4722O01X-Q11                                                NaN
# AD115O0DR-Q11                                                NaN
# AD115O0AJ-A12  [{'id': 'Qe78PYDCQwK', 'url_key': '/outfits/Qe...
#
# [29064 rows x 17 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
df.brand_name.value_counts().index[0]
# Out:
# 'adidas Originals'

# %%
df['price.original']
# Out:
# sku
# SK212O01T-Q11    69,95 €
# VA215O03L-G11    79,95 €
# PU122E02F-K11    85,00 €
# GU122O0EW-K11    34,95 €
# OS322E04A-C11    39,95 €
#                   ...
# PUC12O08V-A11    29,99 €
# C1822O04Z-A11    29,95 €
# L4722O01X-Q11    49,95 €
# AD115O0DR-Q11    79,95 €
# AD115O0AJ-A12    99,95 €
# Name: price.original, Length: 29064, dtype: object

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
df1['discount_amount']
# Out:
# sku
# SK212O01T-Q11    31.50
# VA215O03L-G11    32.00
# PU122E02F-K11    26.00
# GU122O0EW-K11    14.00
# OS322E04A-C11     3.96
#                  ...
# PUC12O08V-A11    14.00
# C1822O04Z-A11     6.00
# L4722O01X-Q11    12.50
# AD115O0DR-Q11    12.00
# AD115O0AJ-A12    15.00
# Name: discount_amount, Length: 29064, dtype: float64

# %%
total_disc=df1.groupby(['sku']).sum().discount_amount

total_disc.sort_values(ascending=False)
# Out:
# sku
# C1812O00I-Q11    27334.0
# PU115O056-Q11    23528.0
# NI112O09A-C11    22144.0
# NI112O08H-A11    22144.0
# AI222D007-K11    20760.0
#                   ...
# PI922QA02-K11     1314.8
# OS322Q07F-G11     1245.6
# VA222O03F-M11     1038.0
# PI922D01Q-K00     1038.0
# GOG22G005-K11      960.0
# Name: discount_amount, Length: 85, dtype: float64

# %%
df1.loc['C1812O00I-Q11']
# Out:
#                                           name                         sizes  \
# sku
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# ...                                        ...                           ...
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
# C1812O00I-Q11  MARVIN - Baskets basses - black  [40, 41, 42, 43, 44, 45, 46]
#
#                                                          url_key  \
# sku
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# ...                                                          ...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
# C1812O00I-Q11  calvin-klein-jeans-marvin-baskets-basses-c1812...
#
#                                                            media  \
# sku
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# ...                                                          ...
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
# C1812O00I-Q11  [{'path': 'C1/81/2O/00/IQ/11/C1812O00I-Q11@22....
#
#                        brand_name  is_premium  \
# sku
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# ...                           ...         ...
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
# C1812O00I-Q11  Calvin Klein Jeans       False
#
#                                                  family_articles  \
# sku
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# ...                                                          ...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
# C1812O00I-Q11  [{'sku': 'C1812O00I-Q11', 'url_key': 'calvin-k...
#
#                                                            flags  \
# sku
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# ...                                                          ...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
# C1812O00I-Q11  [{'key': 'discountRate', 'value': '-45%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# ...                     ...               ...            ...
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
# C1812O00I-Q11          shoe                []         174.95
#
#               price.promotional  price.has_different_prices  \
# sku
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# ...                         ...                         ...
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
# C1812O00I-Q11             95.95                       False
#
#                price.has_different_original_prices  \
# sku
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# ...                                            ...
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
# C1812O00I-Q11                                False
#
#                price.has_different_promotional_prices  \
# sku
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# ...                                               ...
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
# C1812O00I-Q11                                   False
#
#                price.has_discount_on_selected_sizes_only outfits  \
# sku
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# ...                                                  ...     ...
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
# C1812O00I-Q11                                      False     NaN
#
#                discount_amount
# sku
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# ...                        ...
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
# C1812O00I-Q11             79.0
#
# [346 rows x 18 columns]
