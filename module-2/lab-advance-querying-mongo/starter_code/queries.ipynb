# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client=MongoClient()
db=client.DB

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
a = db.db.find({'name':'Babelgum'},{'name':1})
ax = pd.DataFrame(a)
ax.head()
# Out:
#                         _id      name
# 0  52cdef7c4bab8bd675297da0  Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
b = db.db.find({'number_of_employees':{'$gt':5000}},{'name':1,'number_of_employees':1,'_id':0}).limit(20).sort("number_of_employees", pymongo.DESCENDING)
bx = pd.DataFrame(b)
bx
#se identificó que el registro 16 y 17 (Mitsubishi Electric) están repetidos, pero cuentan con diferente '_id'.
# No se va a borrar para no afectar la base de datos general, por el momento.
# Out:
#                                           name  number_of_employees
# 0                                      Siemens               405000
# 1                                          IBM               388000
# 2                                       Toyota               320000
# 3                                       PayPal               300000
# 4   Nippon Telegraph and Telephone Corporation               227000
# 5                          Samsung Electronics               221726
# 6                                    Accenture               205000
# 7                    Tata Consultancy Services               200300
# 8                    Flextronics International               200000
# 9                                      Safeway               186000
# 10                                        Sony               180500
# 11                                          LG               177000
# 12                                        Ford               171000
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
c = db.db.find({'founded_year':{'$gte':2000, '$lte':2005}},
               {'name':1,'founded_year':1,'_id':0})
cx = pd.DataFrame(c)
cx.head()
# Out:
#         name  founded_year
# 0   Wetpaint          2005
# 1       Zoho          2005
# 2       Digg          2004
# 3   Facebook          2004
# 4  Omnidrive          2005

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
d = db.db.find({'ipo.valuation_amount':{'$gt':100000},'founded_year':{'$lt':2010}}
               ,{'name':1,'ipo':1,'_id':0})
dx = pd.DataFrame(d)
dx.head()
# Out:
#        name                                                ipo
# 0  Facebook  {'valuation_amount': 104000000000, 'valuation_...
# 1   Twitter  {'valuation_amount': 18100000000, 'valuation_c...
# 2      Yelp  {'valuation_amount': 1300000000, 'valuation_cu...
# 3  LinkedIn  {'valuation_amount': 9310000000, 'valuation_cu...
# 4    Amazon  {'valuation_amount': 100000000000, 'valuation_...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
e = db.db.find({'number_of_employees':{'$lt':1000},'founded_year':{'$lt':2005}}).limit(10).sort("number_of_employees", pymongo.DESCENDING)
ex = pd.DataFrame(e)
ex
# Out:
#                         _id                             name  \
# 0  52cdef7d4bab8bd675298933             Infinera Corporation
# 1  52cdef7e4bab8bd67529ac95  NorthPoint Communications Group
# 2  52cdef7f4bab8bd67529be17                     888 Holdings
# 3  52cdef7c4bab8bd6752986a2               Forrester Research
# 4  52cdef7e4bab8bd67529af6d                        SonicWALL
# 5  52cdef7e4bab8bd67529b21b                       Webmetrics
# 6  52cdef7e4bab8bd67529b3bd             Cornerstone OnDemand
# 7  52cdef7c4bab8bd675297de0                             Yelp
# 8  52cdef7c4bab8bd675297ef5                          MySpace
# 9  52cdef7c4bab8bd675297efd                         ZoomInfo
#
#                          permalink  \
# 0                         infinera
# 1  northpoint-communications-group
# 2                     888-holdings
# 3               forrester-research
# 4                        sonicwall
# 5                       webmetrics
# 6             cornerstone-ondemand
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
f = db.db.find({'partners':{'$exists': False }})
fx = pd.DataFrame(f)
fx.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
g = db.db.find({'category_code':None})
gx = pd.DataFrame(g)
gx.head()
# Out:
#                         _id          name     permalink  \
# 0  52cdef7c4bab8bd6752980f6    Collective    collective
# 1  52cdef7c4bab8bd675298225       Snimmer       snimmer
# 2  52cdef7c4bab8bd675298226        KoolIM        koolim
# 3  52cdef7c4bab8bd675298261  Level9 Media  level9-media
# 4  52cdef7c4bab8bd675298262       VidKing       vidking
#
#                                    crunchbase_url            homepage_url  \
# 0    http://www.crunchbase.com/company/collective                    None
# 1       http://www.crunchbase.com/company/snimmer                    None
# 2        http://www.crunchbase.com/company/koolim                    None
# 3  http://www.crunchbase.com/company/level9-media                    None
# 4       http://www.crunchbase.com/company/vidking  http://www.VidKing.com
#
#   blog_url blog_feed_url twitter_username category_code  number_of_employees  \
# 0     None          None             None          None                  NaN
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
h = db.db.find({'number_of_employees':{'$gte':100,'$lt':1000}},{'name':1,'number_of_employees':1,'_id':0})
hx = pd.DataFrame(h)
hx
# Out:
#                       name  number_of_employees
# 0                AdventNet                  600
# 1                  AddThis                  120
# 2                    OpenX                  305
# 3                 LifeLock                  644
# 4                    Jajah                  110
# ..                     ...                  ...
# 912  UOL (Universo Online)                  500
# 913               NextLabs                  100
# 914      OfficialVirtualDJ                  102
# 915          Willdan Group                  385
# 916                   QSGI                  164
#
# [917 rows x 2 columns]

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
i = db.db.find({'ipo':{'$ne':None}}).sort('ipo', pymongo.DESCENDING)
ix = pd.DataFrame(i)
ix.head()
# Out:
#                         _id      name permalink  \
# 0  52cdef7e4bab8bd67529a8b4      GREE      gree
# 1  52cdef7c4bab8bd675297d8e  Facebook  facebook
# 2  52cdef7c4bab8bd675297e7a    Amazon    amazon
# 3  52cdef7c4bab8bd675297d94   Twitter   twitter
# 4  52cdef7d4bab8bd675299d5d   Groupon   groupon
#
#                                crunchbase_url              homepage_url  \
# 0      http://www.crunchbase.com/company/gree  http://www.gree-corp.com
# 1  http://www.crunchbase.com/company/facebook       http://facebook.com
# 2    http://www.crunchbase.com/company/amazon         http://amazon.com
# 3   http://www.crunchbase.com/company/twitter        http://twitter.com
# 4   http://www.crunchbase.com/company/groupon    http://www.groupon.com
#
#                        blog_url                             blog_feed_url  \
# 0
# 1      http://blog.facebook.com         http://blog.facebook.com/atom.php
# 2
# 3       http://twitter.com/blog   http://feeds.feedburner.com/TwitterBlog
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
j = db.db.find({}).limit(10).sort("number_of_employees", pymongo.DESCENDING)
jx = pd.DataFrame(j)
jx
# Out:
#                         _id                                        name  \
# 0  52cdef7d4bab8bd67529941a                                     Siemens
# 1  52cdef7c4bab8bd67529856a                                         IBM
# 2  52cdef7d4bab8bd675299d33                                      Toyota
# 3  52cdef7c4bab8bd675297e89                                      PayPal
# 4  52cdef7e4bab8bd67529b0fe  Nippon Telegraph and Telephone Corporation
# 5  52cdef7d4bab8bd675298aa4                         Samsung Electronics
# 6  52cdef7d4bab8bd675298b99                                   Accenture
# 7  52cdef7e4bab8bd67529a657                   Tata Consultancy Services
# 8  52cdef7e4bab8bd67529aa51                   Flextronics International
# 9  52cdef7d4bab8bd675299156                                     Safeway
#
#                                     permalink  \
# 0                                     siemens
# 1                                         ibm
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
k = db.db.find({'founded_month':{'$gte':7}}).limit(1000)
kx = pd.DataFrame(k)
kx.head()
# Out:
#                         _id       name  permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint       abc2
# 1  52cdef7c4bab8bd675297d8c       Zoho       abc4
# 2  52cdef7c4bab8bd675297d8d       Digg       digg
# 3  52cdef7c4bab8bd675297d8f  Omnidrive  omnidrive
# 4  52cdef7c4bab8bd675297d9b       eBay       ebay
#
#                                 crunchbase_url              homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint   http://wetpaint-inc.com
# 1       http://www.crunchbase.com/company/zoho           http://zoho.com
# 2       http://www.crunchbase.com/company/digg       http://www.digg.com
# 3  http://www.crunchbase.com/company/omnidrive  http://www.omnidrive.com
# 4       http://www.crunchbase.com/company/ebay           http://ebay.com
#
#                         blog_url                          blog_feed_url  \
# 0    http://digitalquarters.net/       http://digitalquarters.net/feed/
# 1         http://blogs.zoho.com/             http://blogs.zoho.com/feed
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
l = db.db.find({'deadpooled_year':{'$ne':None}})
lx = pd.DataFrame(l)
lx = lx.assign(deadpool3=lx.deadpooled_year-lx.founded_year)
lx = lx[lx.deadpool3>=3]
lx
# Out:
#                           _id              name         permalink  \
# 3    52cdef7c4bab8bd675297d8f         Omnidrive         omnidrive
# 4    52cdef7c4bab8bd675297da0          Babelgum          babelgum
# 6    52cdef7c4bab8bd675297dae             Thoof             thoof
# 8    52cdef7c4bab8bd675297db6            Wesabe            wesabe
# 9    52cdef7c4bab8bd675297db7         Jangl SMS         jangl-sms
# ..                        ...               ...               ...
# 911  52cdef7f4bab8bd67529c470         SpeakSoft         speaksoft
# 914  52cdef7f4bab8bd67529c4c4            Tagito            tagito
# 917  52cdef7f4bab8bd67529c503  Nordic Windpower  nordic-windpower
# 922  52cdef7f4bab8bd67529c5aa    Nethra Imaging    nethra-imaging
# 925  52cdef7f4bab8bd67529c68b           Prolify           prolify
#
#                                         crunchbase_url  \
# 3          http://www.crunchbase.com/company/omnidrive
# 4           http://www.crunchbase.com/company/babelgum
# ...

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
m = db.db.find({'founded_year':{'$lt':2000},'acquisition.price_amount':{'$gt':10000000}})
mx = pd.DataFrame(m)
mx.head()
# Out:
#                         _id        name   permalink  \
# 0  52cdef7c4bab8bd675297d90     Postini     postini
# 1  52cdef7c4bab8bd675297deb    SideStep    sidestep
# 2  52cdef7c4bab8bd675297e2c  Recipezaar  recipezaar
# 3  52cdef7c4bab8bd675297e89      PayPal      paypal
# 4  52cdef7c4bab8bd675297e97    Snapfish    snapfish
#
#                                  crunchbase_url               homepage_url  \
# 0     http://www.crunchbase.com/company/postini         http://postini.com
# 1    http://www.crunchbase.com/company/sidestep    http://www.sidestep.com
# 2  http://www.crunchbase.com/company/recipezaar  http://www.recipezaar.com
# 3      http://www.crunchbase.com/company/paypal      http://www.paypal.com
# 4    http://www.crunchbase.com/company/snapfish        http://snapfish.com
#
#                               blog_url blog_feed_url twitter_username  \
# 0                                                                None
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
n = db.db.find({'acquisition.acquired_year':{'$gte':2015}},{'name':1,'acquisition':1,'_id':0}).sort('acquisition.price_amount', pymongo.DESCENDING)
nx = pd.DataFrame(n)
nx.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
o = db.db.find({},{'name':1,'founded_year':1,'_id':0})
ox = pd.DataFrame(o).sort_values('founded_year')
ox.head()
# Out:
#                       name  founded_year
# 3536           SmallWorlds        1800.0
# 261             Alstrasoft        1800.0
# 13362              US Army        1800.0
# 18121               DuPont        1802.0
# 12048  Bachmann Industries        1833.0

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
p = db.db.find({'founded_day':{'$lte':7}}).limit(10).sort('acquisition.price_amount', pymongo.DESCENDING)
px = pd.DataFrame(p)
px.head()
# Out:
#                         _id      name permalink  \
# 0  52cdef7d4bab8bd6752989a1  Netscape  netscape
# 1  52cdef7c4bab8bd675297e89    PayPal    paypal
# 2  52cdef7c4bab8bd675297efe    Zappos    zappos
# 3  52cdef7c4bab8bd675297f0c   Alibaba   alibaba
# 4  52cdef7c4bab8bd675297d90   Postini   postini
#
#                                crunchbase_url             homepage_url  \
# 0  http://www.crunchbase.com/company/netscape  http://netscape.aol.com
# 1    http://www.crunchbase.com/company/paypal    http://www.paypal.com
# 2    http://www.crunchbase.com/company/zappos    http://www.zappos.com
# 3   http://www.crunchbase.com/company/alibaba   http://www.alibaba.com
# 4   http://www.crunchbase.com/company/postini       http://postini.com
#
#                             blog_url                            blog_feed_url  \
# 0
# 1
# 2  http://www.blogs.zappos.com/blogs  http://feeds.feedburner.com/ZapposBlogs
# 3
# 4
#
#   twitter_username category_code  number_of_employees  ...  \
# ...

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
q = db.db.find({'category_code':'web','number_of_employees':{'$gt':4000}}).sort('number_of_employees',pymongo.ASCENDING)
qx = pd.DataFrame(q)
qx.head()
# Out:
#                         _id                           name  \
# 0  52cdef7c4bab8bd67529822a                        Expedia
# 1  52cdef7c4bab8bd675297e96                            AOL
# 2  52cdef7c4bab8bd675297ea4                        Webkinz
# 3  52cdef7c4bab8bd675297fcb                        Rakuten
# 4  52cdef7c4bab8bd67529834c  Los Angeles Times Media Group
#
#                        permalink  \
# 0                        expedia
# 1                            aol
# 2                        webkinz
# 3                        rakuten
# 4  los-angeles-times-media-group
#
#                                       crunchbase_url  \
# 0          http://www.crunchbase.com/company/expedia
# 1              http://www.crunchbase.com/company/aol
# 2          http://www.crunchbase.com/company/webkinz
# 3          http://www.crunchbase.com/company/rakuten
# 4  http://www.crunchbase.com/company/los-angeles-...
#
#                      homepage_url                      blog_url  \
# ...

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
r = db.db.find({'acquisition.price_currency_code':'EUR','acquisition.price_amount':{'$gt':10000000}})
rx = pd.DataFrame(r)
rx.head()
# Out:
#                         _id               name          permalink  \
# 0  52cdef7c4bab8bd675297f02                ZYB                zyb
# 1  52cdef7d4bab8bd675298bf3            Apertio            apertio
# 2  52cdef7d4bab8bd675298f47  Greenfield Online  greenfield-online
# 3  52cdef7e4bab8bd67529a536            Webedia            webedia
# 4  52cdef7e4bab8bd67529a729          Wayfinder          wayfinder
#
#                                       crunchbase_url  \
# 0              http://www.crunchbase.com/company/zyb
# 1          http://www.crunchbase.com/company/apertio
# 2  http://www.crunchbase.com/company/greenfield-o...
# 3          http://www.crunchbase.com/company/webedia
# 4        http://www.crunchbase.com/company/wayfinder
#
#                                    homepage_url  \
# 0                                http://zyb.com
# 1                        http://www.apertio.com
# 2  http://www.greenfield.com/content/index.html
# ...

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
s = db.db.find({'acquisition.acquired_month':{'$lte':3}},{'name':1,'acquisition':1,'_id':0}).limit(10)
sx = pd.DataFrame(s)
sx.head()
# Out:
#          name                                        acquisition
# 0        Kyte  {'price_amount': None, 'price_currency_code': ...
# 1  NetRatings  {'price_amount': 327000000, 'price_currency_co...
# 2      blogTV  {'price_amount': None, 'price_currency_code': ...
# 3  Livestream  {'price_amount': None, 'price_currency_code': ...
# 4    iContact  {'price_amount': 169000000, 'price_currency_co...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
t = db.db.find({'acquisition.acquired_year':{'$not':{'$gte':2011}},'founded_year':{'$gte':2000},'founded_year':{'$lte':2010}},{'founded_year':1,'acquisition':1})
tx = pd.DataFrame(t)
tx.head()
# Out:
#                         _id  founded_year  \
# 0  52cdef7c4bab8bd675297d8b          1996
# 1  52cdef7c4bab8bd675297d8c          2005
# 2  52cdef7c4bab8bd675297d8e          2004
# 3  52cdef7c4bab8bd675297d8f          2005
# 4  52cdef7c4bab8bd675297d90          1999
#
#                                          acquisition
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'price_amount': 625000000, 'price_currency_co...
