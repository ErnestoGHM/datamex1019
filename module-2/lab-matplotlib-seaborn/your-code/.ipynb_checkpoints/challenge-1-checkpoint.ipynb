# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
sns.palplot(sns.husl_palette(10,l=.55,s=.9))

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.figure(figsize = (15,4))
sns.set_style("white")
plt.subplot(1,2,1)
plt.plot(x,y, sns.xkcd_rgb["faded green"], lw=3)
plt.subplot(1,2,2)
plt.plot(x,z, sns.xkcd_rgb["dusty purple"], lw=3)
sns.despine(left = True, trim=True);
plt.show();

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, ax = plt.subplots(1,2, figsize = (15,4))
ax[0].plot(x,y, sns.xkcd_rgb["amber"], lw=3)
ax[1].plot(x,z, sns.xkcd_rgb["windows blue"], lw=3)
sns.despine(left = True, trim=True)
plt.show();

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, ax = plt.subplots(1,2, figsize = (20,5))
ax[0].plot(x,y, sns.xkcd_rgb["amber"], lw=3)
ax[1].plot(x,z, sns.xkcd_rgb["windows blue"], lw=3)
sns.despine(left = True, trim=True)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, ax = plt.subplots(1,2, figsize = (20,5))
ax[0].plot(x,y, sns.xkcd_rgb["amber"], lw=3)
ax[0].set_xlabel('Eje X')
ax[0].set_ylabel('Eje Y')

ax[1].plot(x,z, sns.xkcd_rgb["windows blue"], lw=3)
ax[1].set_xlabel('Eje X')
ax[1].set_ylabel('Eje Y')

sns.despine(left = True, trim=True)
plt.show();

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, ax = plt.subplots(1,2, figsize = (10,4))
ax[0].plot(x,np.exp(x),y)
ax[0].set_xlabel('Eje X')
ax[0].set_ylabel('Eje Y')
ax[0].set_yscale('linear')

ax[1].plot(x,np.exp(x),y)
ax[1].set_xlabel('Eje X')
ax[1].set_ylabel('Eje Y')
ax[1].set_yscale('log')

sns.despine(left = True, trim=True)
plt.show();

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
dat = pd.read_csv('vehicles.csv')
dat.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
sns.set_palette("husl", 8)
plt.scatter(dat['Combined MPG'], dat['Highway MPG'])
plt.xlabel('Combined MPG')
plt.ylabel('Highway MPG');
sns.despine(trim=True)
plt.show();

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
plt.figure(figsize=(5,10))
sns.set_palette("husl", 12)
plt.boxplot(dat['CO2 Emission Grams/Mile'])
plt.title('CO2 Emission Grams/Mile')
sns.despine(trim=True)
plt.show();

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(dat['Fuel Barrels/Year'],bins=10)
plt.xlabel('Fuel Barrels/Year')
sns.despine(trim = True)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
ftype = dat.groupby(['Fuel Type']).agg({'City MPG':'mean'})
ftype
# Out:
#                               City MPG
# Fuel Type
# CNG                          15.966667
# Diesel                       21.173436
# Gasoline or E85              15.347280
# Gasoline or natural gas      13.700000
# Gasoline or propane          12.000000
# Midgrade                     14.851351
# Premium                      16.793166
# Premium Gas or Electricity   30.705882
# Premium and Electricity      24.900000
# Premium or E85               17.305785
# Regular                      17.970195
# Regular Gas and Electricity  43.125000
# Regular Gas or Electricity   43.000000

# %%
ftype.plot.bar()
plt.xlabel('Fuel Type')
plt.ylabel('City MPG')
sns.despine(trim = True)
plt.show();
