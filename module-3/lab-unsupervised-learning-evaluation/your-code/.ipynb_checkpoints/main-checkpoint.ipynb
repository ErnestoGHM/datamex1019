# %% [markdown]
# # Unsupervised Learning Model Evaluation Lab
#
# Complete the exercises below to solidify your knowledge and understanding of unsupervised learning model evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import silhouette_score
from sklearn import cluster, datasets
from sklearn.cluster import KMeans

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %% [markdown]
# ## 1. Train a KMeans clustering model on the data set using 8 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=8)
kmeans.fit(X)
y_pred=kmeans.predict(X)

# %%
silhouette_score(X, y_pred)
# Out:
# 0.5406824747857625

# %% [markdown]
# ## 2. Train a KMeans clustering model on the data set using 5 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=5)
kmeans.fit(X)
y_pred=kmeans.predict(X)

# %%
silhouette_score(X, y_pred)
# Out:
# 0.5489993239795691

# %% [markdown]
# ## 3. Train a KMeans clustering model on the data set using 3 clusters and compute the silhouette score for the model.

# %%
kmeans=cluster.KMeans(n_clusters=3)
kmeans.fit(X)
y_pred=kmeans.predict(X)
silhouette_score(X, y_pred)
# Out:
# 0.5711381937868844

# %% [markdown]
# ## 4. Use elbow curve visualizations to see if you can determine the best number of clusters to use.
#
# The Yellowbrick library has 3 metrics that you can plot using the `metric` parameter:
#
# - **distortion**: mean sum of squared distances to centers
# - **silhouette**: mean ratio of intra-cluster and nearest-cluster distance
# - **calinski_harabaz**: ratio of within to between cluster dispersion

# %%
from yellowbrick.cluster import KElbowVisualizer
modelo=KMeans()
visual=KElbowVisualizer(modelo, k=(1,10),metric='distortion')
visual.fit(X)
visual.poof();

# %% [markdown]
# ## 5. Try performing the same elbow tests with an AgglomerativeClustering model and compare the results you get to the KMeans results.

# %%
modeloaglo=cluster.AgglomerativeClustering(n_clusters=2, linkage='single')
visualaglo=KElbowVisualizer(modeloaglo, k=(1,10),metric='distortion')
visualaglo.fit(X)
visualaglo.poof();

# %% [markdown]
# ## 6. Create and plot a scatter matrix showing how the clusters are grouped across all the different combinations of variables in the data.
#
# Use the model and number of clusters that returned the best result above.

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(X)
y_pred=kmeans.predict(X)

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
plt.figure(figsize=(15,7))
plt.subplot(2,6,1)
plt.scatter(X['alcohol'], X['malic_acid'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,2)
plt.scatter(X['alcohol'], X['ash'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,3)
plt.scatter(X['alcohol'], X['alcalinity_of_ash'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,4)
plt.scatter(X['alcohol'], X['magnesium'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,5)
plt.scatter(X['alcohol'], X['total_phenols'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,6)
plt.scatter(X['alcohol'], X['flavanoids'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,7)
plt.scatter(X['alcohol'], X['nonflavanoid_phenols'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,8)
plt.scatter(X['alcohol'], X['proanthocyanins'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,9)
plt.scatter(X['alcohol'], X['color_intensity'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,10)
plt.scatter(X['alcohol'], X['hue'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,11)
plt.scatter(X['alcohol'], X['od280/od315_of_diluted_wines'], c=y_pred, cmap='Spectral')
plt.subplot(2,6,12)
plt.scatter(X['alcohol'], X['proline'], c=y_pred, cmap='Spectral')

plt.show();

# %% [markdown]
# ## 7. Apply a PCA transform and plot the first two principle components with the plot point colors determined by cluster.

# %%
from sklearn.decomposition import PCA

pca=PCA().fit(X)
pca_x=pca.transform(X)
pca.explained_variance_ratio_
# Out:
# array([9.98091230e-01, 1.73591562e-03, 9.49589576e-05, 5.02173562e-05,
#        1.23636847e-05, 8.46213034e-06, 2.80681456e-06, 1.52308053e-06,
#        1.12783044e-06, 7.21415811e-07, 3.78060267e-07, 2.12013755e-07,
#        8.25392788e-08])

# %%
pca_x.shape
# Out:
# (178, 13)

# %%
plt.scatter(pca_x[:,0], pca_x[:,1], c = y_pred)
ax[0].set_xlabel('PCA 1')
ax[0].set_ylabel('PCA 2')


plt.show();

# %% [markdown]
# ## 8. Generate a series of t-SNE plots showing the clusters at a variety of perplexities.

# %%
from sklearn.manifold import TSNE

fig, ax=plt.subplots(1, 4, figsize=(17,7))

for i, p in enumerate([5, 30, 50, 100]):
    tsne=TSNE(perplexity=p)
    x_emb=tsne.fit_transform(X)
    ax[i].scatter(x_emb[:,0], x_emb[:,1], c=y, cmap='Spectral')
    ax[i].set_title('Perplexity={}'.format(p))
    
plt.show();
